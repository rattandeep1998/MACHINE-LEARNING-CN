# %%
from sklearn import datasets
from nltk.tokenize import word_tokenize
import string
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/rattandeep/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
cats = ['alt.atheism', 'sci.space']
newsgroups_train = datasets.fetch_20newsgroups(subset='train', categories=cats)

# %%
type(newsgroups_train)
# Out:
# sklearn.utils.Bunch

# %%
curClass = {}
curClass['totalfiles'] = 0

dict = {}
index = []
import os
path = '20_newsgroups/alt.atheism/'
for filename in os.listdir(path):
    #print(filename)
    index.append(filename)
    f = open(path + filename,'r',encoding='utf-8', errors='ignore')
    message = f.read()
    
    tokens = word_tokenize(message)    
    tokens = [w.lower() for w in tokens]

    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    words = [word for word in stripped if word.isalpha()]
    stop_words = set(stopwords.words('english'))
    words = [w for w in words if not w in stop_words]
    
    #print(words)
    #words = message.split(" ")
    #print(words)
    
    for word in words:
        if word not in dict:
            dict[word] = 0
        dict[word] += 1

# %%
len(dict)
# Out:
# 15908

# %%
dict
# Out:
# {'path': 1008,
#  'cantaloupesrvcscmuedu': 1266,
#  'crabapplesrvcscmuedu': 356,
#  'newsseicmuedu': 308,
#  'cisohiostateedu': 216,
#  'zaphodmpsohiostateedu': 449,
#  'howlandrestonansnet': 600,
#  'solctrcolumbiaedu': 58,
#  'ursa': 18,
#  'pooh': 15,
#  'halat': 166,
#  'poohbears': 45,
#  'jim': 201,
#  'newsgroups': 1011,
#  'altatheism': 1165,
#  'subject': 1093,
#  'inimitable': 27,
#  'rushdie': 166,
#  'anecdote': 17,
#  'islam': 258,
#  'messageid': 1000,
#  'ursabearcom': 72,
#  'date': 1054,
#  'apr': 1076,
#  'gmt': 900,
#  'references': 955,
#  'unixportalcom': 23,
#  'buedu': 199,
#  'mantiscouk': 309,
#  'sender': 458,
#  'news': 517,
#  'bearcom': 30,
#  'replyto': 78,
#  'lines': 1050,
#  'article': 978,
#  'writes': 1232,
#  'jaeger': 167,
#  'buphybuedu': 94,
#  'gregg': 114,
#  'precise': 12,
#  'rejection': 5,
#  'god': 1131,
#  'leaving': 14,
#  'one': 1219,
#  'perfectly': 34,
#  'free': 152,
#  'muslim': 120,
#  'doubt': 88,
#  'question': 256,
# ...

# %%
columns = dict.keys()

# %%
df = pd.DataFrame(0, index = index, columns = columns)
df
# Out:
#        path  cantaloupesrvcscmuedu  crabapplesrvcscmuedu  newsseicmuedu  \
# 53239     0                      0                     0              0
# 51309     0                      0                     0              0
# 53473     0                      0                     0              0
# 53458     0                      0                     0              0
# 51262     0                      0                     0              0
# 51312     0                      0                     0              0
# 53361     0                      0                     0              0
# 51163     0                      0                     0              0
# 53073     0                      0                     0              0
# 54171     0                      0                     0              0
# 53252     0                      0                     0              0
# 51120     0                      0                     0              0
# ...

# %%
curClass = {}
curClass['totalfiles'] = 0

dict = {}
index = []
import os
path = '20_newsgroups/alt.atheism/'
for filename in os.listdir(path):
    #print(filename)
    curClass['totalfiles'] += 1
    
    #print(type(filename))
    
    if filename not in curClass:
        curClass[filename] = {} 
    
    index.append(filename)
    f = open(path + filename,'r',encoding='utf-8', errors='ignore')
    message = f.read()
    
    tokens = word_tokenize(message)    
    tokens = [w.lower() for w in tokens]

    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    words = [word for word in stripped if word.isalpha()]
    stop_words = set(stopwords.words('english'))
    words = [w for w in words if not w in stop_words]
    
    #print(words)
    #words = message.split(" ")
    #print(words)
    
    for word in words:
        if word not in curClass[filename]:
            curClass[filename][word] = 0
        curClass[filename][word] += 1

# %%
curClass
# Out:
# {'totalfiles': 1000,
#  '53239': {'actually': 1,
#   'add': 1,
#   'also': 1,
#   'altatheism': 1,
#   'anecdote': 1,
#   'apr': 1,
#   'article': 2,
#   'atheism': 1,
#   'bearcom': 1,
#   'buedu': 3,
#   'buphybuedu': 1,
#   'cantaloupesrvcscmuedu': 1,
#   'choose': 1,
#   'cisohiostateedu': 1,
#   'clear': 1,
#   'committed': 1,
#   'crabapplesrvcscmuedu': 1,
#   'crime': 1,
#   'date': 1,
#   'doubt': 1,
#   'existence': 1,
#   'free': 1,
#   'front': 1,
#   'gmt': 1,
#   'god': 4,
#   'gregg': 1,
#   'halat': 8,
#   'howlandrestonansnet': 1,
#   'impossible': 1,
#   'inimitable': 1,
#   'islam': 2,
#   'issue': 1,
#   'jaeger': 2,
#   'jim': 4,
#   'leaving': 1,
#   'legal': 1,
#   'lines': 1,
#   'long': 1,
#   'made': 1,
#   'mantiscouk': 1,
#   'messageid': 1,
#   'muslim': 1,
#   'news': 1,
#   'newsgroups': 1,
#   'newsseicmuedu': 1,
#   'number': 1,
#   'one': 3,
#   'path': 1,
#   'perfectly': 1,
#   'pooh': 1,
#   'poohbears': 3,
#   'precise': 1,
#   'proper': 1,
# ...

# %%
dict
# Out:
# {'Path:': 18,
#  'cantaloupe.srv.cs.cmu.edu!crabapple.srv.cs.cmu.edu!bb3.andrew.cmu.edu!news.sei.cmu.edu!cis.ohio-state.edu!zaphod.mps.ohio-state.edu!howland.reston.ans.net!sol.ctr.columbia.edu!ursa!pooh!halat\nFrom:': 1,
#  'halat@pooh.bears': 5,
#  '(Jim': 5,
#  'Halat)\nNewsgroups:': 2,
#  'alt.atheism\nSubject:': 18,
#  'Re:': 46,
#  'The': 36,
#  'Inimitable': 3,
#  'Rushdie': 6,
#  '(Re:': 2,
#  'An': 2,
#  'Anecdote': 2,
#  'about': 31,
#  'Islam\nMessage-ID:': 2,
#  '<30123@ursa.bear.com>\nDate:': 1,
#  '15': 6,
#  'Apr': 47,
#  '93': 14,
#  '21:42:03': 1,
#  'GMT\nReferences:': 12,
#  '<C5563u.G6D@unix.portal.com>': 2,
#  '<114540@bu.edu>': 2,
#  '<930413.130539.3O8.rusnews.w165w@mantis.co.uk>': 2,
#  '<115288@bu.edu>': 1,
#  '<30121@ursa.bear.com>\nSender:': 1,
#  'news@bear.com\nReply-To:': 2,
#  'Halat)\nLines:': 2,
#  '37\n\nIn': 3,
#  'article': 26,
#  '<30121@ursa.bear.com>,': 1,
#  'Halat)': 1,
#  'writes:\n>In': 2,
#  '<115288@bu.edu>,': 2,
# ...
