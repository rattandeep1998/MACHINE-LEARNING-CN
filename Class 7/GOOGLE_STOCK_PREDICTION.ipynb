# %%
import quandl
from sklearn.linear_model import LinearRegression
from sklearn import cross_validation
import matplotlib.pyplot as plt
import math

# %%
df = quandl.get("WIKI/GOOGL")
df.head()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0  50.159839  52.191109  48.128568   50.322842
# 2004-08-20          1.0  50.661387  54.708881  50.405597   54.322689
# 2004-08-23          1.0  55.551482  56.915693  54.693835   54.869377
# 2004-08-24          1.0  55.792225  55.972783  51.945350   52.597363
# 2004-08-25          1.0  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  3402.000000  3402.000000  3402.000000  3402.000000  3.402000e+03
# mean    593.277571   598.686217   587.330522   593.068854  7.854607e+06
# std     223.892670   224.624165   222.910084   223.885920  8.262469e+06
# min      99.090000   101.740000    95.960000   100.010000  5.211410e+05
# 25%     460.235000   464.592500   455.002500   460.082500  2.458321e+06
# 50%     564.160000   568.775000   558.670000   563.850000  5.111800e+06
# 75%     732.157500   736.264925   723.252500   730.487500  1.030208e+07
# max    1226.800000  1228.880000  1218.600000  1220.170000  8.215110e+07
#
#        Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# count  3402.000000       3402.0  3402.000000  3402.000000  3402.000000
# mean      0.166952          1.0   404.684669   408.203439   400.788041
# std       9.737770          0.0   252.390137   253.826863   250.737912
# ...

# %%
del df['Open']
del df['High']
del df['Low']
del df['Close']
del df['Volume']
del df['Split Ratio']
del df['Ex-Dividend']

# %%
df.head()
# Out:
#             Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# Date
# 2004-08-19  50.159839  52.191109  48.128568   50.322842   44659000.0
# 2004-08-20  50.661387  54.708881  50.405597   54.322689   22834300.0
# 2004-08-23  55.551482  56.915693  54.693835   54.869377   18256100.0
# 2004-08-24  55.792225  55.972783  51.945350   52.597363   15247300.0
# 2004-08-25  52.542193  54.167209  52.100830   53.164113    9188600.0

# %% [markdown]
# Since open and close are higly correlated, close hata do and percentage change rakh lo....
# Like next day ke liye kitna change ho raha hai...
#
# we can even drop high value and low value with % changes

# %%
df.shape
# Out:
# (3402, 5)

# %%
target = df['Adj. Open'][5:]
target = list(target)
len(target)
# Out:
# 3397

# %%
df[:-5].shape
# Out:
# (3397, 5)

# %%
df = df[:-5]

# %%
df.shape
# Out:
# (3397, 5)

# %%
df['Target'] = target
df.head(10)
# Out:
#             Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume  \
# Date
# 2004-08-19  50.159839  52.191109  48.128568   50.322842   44659000.0
# 2004-08-20  50.661387  54.708881  50.405597   54.322689   22834300.0
# 2004-08-23  55.551482  56.915693  54.693835   54.869377   18256100.0
# 2004-08-24  55.792225  55.972783  51.945350   52.597363   15247300.0
# 2004-08-25  52.542193  54.167209  52.100830   53.164113    9188600.0
# 2004-08-26  52.637487  54.142132  52.492038   54.122070    7094800.0
# 2004-08-27  54.217364  54.478169  53.008633   53.239345    6211700.0
# 2004-08-30  52.802998  52.908323  51.162935   51.162935    5196700.0
# 2004-08-31  51.318415  52.015567  51.238167   51.343492    4917800.0
# 2004-09-01  51.509003  51.644421  49.989312   50.280210    9138200.0
#
#                Target
# Date
# 2004-08-19  52.637487
# 2004-08-20  54.217364
# 2004-08-23  52.802998
# 2004-08-24  51.318415
# 2004-08-25  51.509003
# 2004-08-26  49.698414
# 2004-08-27  50.631294
# ...

# %%
df = df.reset_index()

# %%
date = df['Date']
del df['Date']

# %%
df.head()
# Out:
#    Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume     Target
# 0  50.159839  52.191109  48.128568   50.322842   44659000.0  52.637487
# 1  50.661387  54.708881  50.405597   54.322689   22834300.0  54.217364
# 2  55.551482  56.915693  54.693835   54.869377   18256100.0  52.802998
# 3  55.792225  55.972783  51.945350   52.597363   15247300.0  51.318415
# 4  52.542193  54.167209  52.100830   53.164113    9188600.0  51.509003

# %%
###LINEAR REGRESSION

clf = LinearRegression()

# %%
df.head()
# Out:
#    Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume     Target
# 0  50.159839  52.191109  48.128568   50.322842   44659000.0  52.637487
# 1  50.661387  54.708881  50.405597   54.322689   22834300.0  54.217364
# 2  55.551482  56.915693  54.693835   54.869377   18256100.0  52.802998
# 3  55.792225  55.972783  51.945350   52.597363   15247300.0  51.318415
# 4  52.542193  54.167209  52.100830   53.164113    9188600.0  51.509003

# %%
test_size = 0.2

trainSize = math.ceil((1-test_size)*df.shape[0])

# %%
X_train = df[:trainSize]
Y_train = target[:trainSize]
X_test = df[trainSize:]
Y_test = target[trainSize:]

# %%
#X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(df, target, test_size = 0.2)

# %%
len(X_test)
# Out:
# 679

# %%
Y_train
# Out:
# [52.637486879395404,
#  54.217363808124276,
#  52.802997795738428,
#  51.318415030964623,
#  51.509003358874779,
#  49.698414243728351,
#  50.631293954025402,
#  50.661386847905952,
#  50.525968825443471,
#  51.408693712606279,
#  50.8920990343235,
#  53.480087908050798,
#  53.886341975438228,
#  55.451172457226832,
#  56.343928309016484,
#  57.387148630208884,
#  58.656065655505408,
#  60.28609740736853,
#  58.906839771176656,
#  59.603991812742734,
#  60.67228954550226,
#  59.965106539309332,
#  60.762568227143909,
#  63.460897711766556,
#  65.150613703159436,
#  65.602508659599039,
#  67.846936994856719,
#  67.538484832581076,
#  69.048145008922006,
#  68.491426472131835,
#  69.579786134145053,
#  68.717123176235958,
#  67.453221633252866,
#  71.841768657499742,
#  70.728331583919399,
#  72.699416133095411,
#  71.781582869738642,
#  75.483008817046283,
#  74.199045344809491,
#  72.288146583394564,
#  85.481372808859035,
#  88.41292222105595,
#  93.51316618557783,
# ...

# %%
clf.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
clf.score(X_test, Y_test)
# Out:
# 1.0

# %%
Y_pred = clf.predict(X_test)

# %%
Y_pred
# Out:
# array([  542.73  ,   544.48  ,   545.42  ,   548.    ,   556.52  ,
#          559.41  ,   559.79  ,   562.48  ,   560.3   ,   559.71  ,
#          546.75  ,   545.09  ,   543.66  ,   544.74  ,   542.25  ,
#          547.43  ,   545.6   ,   548.65  ,   553.71  ,   559.51  ,
#          574.5   ,   583.74  ,   589.5   ,   680.    ,   688.98  ,
#          684.88  ,   694.02  ,   691.85  ,   676.77  ,   651.57  ,
#          661.76  ,   662.26  ,   657.44  ,   664.7   ,   657.66  ,
#          664.34  ,   665.75  ,   673.99  ,   667.78  ,   667.09  ,
#          699.58  ,   694.49  ,   689.2   ,   684.04  ,   688.04  ,
#          691.07  ,   690.11  ,   689.1   ,   671.04  ,   600.6   ,
#          646.4675,   643.1   ,   672.    ,   665.11  ,   656.26  ,
#          633.66  ,   638.64  ,   647.93  ,   629.7   ,   641.    ,
#          651.88  ,   643.9   ,   650.21  ,   655.63  ,   656.71  ,
#          665.55  ,   667.49  ,   665.06  ,   665.51  ,   657.47  ,
# ...

# %%
Y_test
# Out:
# [542.73000000000002,
#  544.48000000000002,
#  545.41999999999996,
#  548.0,
#  556.51999999999998,
#  559.40999999999997,
#  559.78999999999996,
#  562.48000000000002,
#  560.29999999999995,
#  559.71000000000004,
#  546.75,
#  545.09000000000003,
#  543.65999999999997,
#  544.74000000000001,
#  542.25,
#  547.42999999999995,
#  545.60000000000002,
#  548.64999999999998,
#  553.71000000000004,
#  559.50999999999999,
#  574.5,
#  583.74000000000001,
#  589.5,
#  680.0,
#  688.98000000000002,
#  684.88,
#  694.01999999999998,
#  691.85000000000002,
#  676.76999999999998,
#  651.57000000000005,
#  661.75999999999999,
#  662.25999999999999,
#  657.44000000000005,
#  664.70000000000005,
#  657.65999999999997,
#  664.34000000000003,
#  665.75,
#  673.99000000000001,
#  667.77999999999997,
#  667.09000000000003,
#  699.58000000000004,
#  694.49000000000001,
#  689.20000000000005,
#  684.03999999999996,
#  688.03999999999996,
#  691.07000000000005,
#  690.11000000000001,
# ...

# %%
plt.plot()

# %%
per = 0.2

train = (1-per)*len(df)
test = per*len(df)

# %%
df[:3000].shape
# Out:
# (3000, 6)

# %%
df
# Out:
#             Ex-Dividend    Adj. Open    Adj. High     Adj. Low   Adj. Close  \
# Date
# 2004-08-19          0.0    50.159839    52.191109    48.128568    50.322842
# 2004-08-20          0.0    50.661387    54.708881    50.405597    54.322689
# 2004-08-23          0.0    55.551482    56.915693    54.693835    54.869377
# 2004-08-24          0.0    55.792225    55.972783    51.945350    52.597363
# 2004-08-25          0.0    52.542193    54.167209    52.100830    53.164113
# 2004-08-26          0.0    52.637487    54.142132    52.492038    54.122070
# 2004-08-27          0.0    54.217364    54.478169    53.008633    53.239345
# 2004-08-30          0.0    52.802998    52.908323    51.162935    51.162935
# 2004-08-31          0.0    51.318415    52.015567    51.238167    51.343492
# 2004-09-01          0.0    51.509003    51.644421    49.989312    50.280210
# 2004-09-02          0.0    49.698414    51.343492    49.623182    50.912161
# ...
