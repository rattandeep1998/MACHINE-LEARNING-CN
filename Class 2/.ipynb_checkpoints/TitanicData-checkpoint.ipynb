# %%
import pandas as pd

titanic = pd.read_csv('titanic_train.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
pd.isnull(titanic).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# del titanic['Name']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic[titanic.Survived == 1].Name
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# 17                          Williams, Mr. Charles Eugene
# 19                               Masselmani, Mrs. Fatima
# 21                                 Beesley, Mr. Lawrence
# 22                           McGowan, Miss. Anna "Annie"
# 23                          Sloper, Mr. William Thompson
# 25     Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 28                         O'Dwyer, Miss. Ellen "Nellie"
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# ...

# %%
titanic.shape
# Out:
# (891, 12)

# %%
del titanic['PassengerId']

# %%
titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
del titanic['Name']
del titanic['Ticket']

# %%
titanic.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %% [markdown]
# For unique entries

# %%
a = titanic.Cabin
a
# Out:
# 0              NaN
# 1              C85
# 2              NaN
# 3             C123
# 4              NaN
# 5              NaN
# 6              E46
# 7              NaN
# 8              NaN
# 9              NaN
# 10              G6
# 11            C103
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             D56
# 22             NaN
# 23              A6
# 24             NaN
# 25             NaN
# 26             NaN
# 27     C23 C25 C27
# 28             NaN
# 29             NaN
#           ...
# 861            NaN
# 862            D17
# 863            NaN
# 864            NaN
# 865            NaN
# 866            NaN
# 867            A24
# 868            NaN
# 869            NaN
# 870            NaN
# 871            D35
# 872    B51 B53 B55
# 873            NaN
# 874            NaN
# 875            NaN
# 876            NaN
# ...

# %%
survived = titanic[titanic.Survived == 1]

# %%
survived.reset_index(drop = True , inplace = True)
survived
# Out:
#      Survived  Pclass     Sex    Age  SibSp  Parch      Fare Cabin Embarked
# 0           1       1  female  38.00      1      0   71.2833   C85        C
# 1           1       3  female  26.00      0      0    7.9250   NaN        S
# 2           1       1  female  35.00      1      0   53.1000  C123        S
# 3           1       3  female  27.00      0      2   11.1333   NaN        S
# 4           1       2  female  14.00      1      0   30.0708   NaN        C
# 5           1       3  female   4.00      1      1   16.7000    G6        S
# 6           1       1  female  58.00      0      0   26.5500  C103        S
# 7           1       2  female  55.00      0      0   16.0000   NaN        S
# 8           1       2    male    NaN      0      0   13.0000   NaN        S
# 9           1       3  female    NaN      0      0    7.2250   NaN        C
# 10          1       2    male  34.00      0      0   13.0000   D56        S
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(titanic.Survived,titanic.Age)
plt.show()

# %%
notsurvived = titanic[titanic.Survived == 0]
notsurvived.reset_index(drop = True , inplace = True)

# %%
survived[survived.Sex == 'female'].Survived.count()
# Out:
# 233

# %%
(survived.Sex == 'female').count()
# Out:
# 342

# %%
survived.Sex == 'male'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8       True
# 9      False
# 10      True
# 11     False
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25     False
# 26     False
# 27     False
# 28      True
# 29     False
#        ...
# 312    False
# 313    False
# 314     True
# 315    False
# 316     True
# 317     True
# 318    False
# 319    False
# 320     True
# 321    False
# 322     True
# 323     True
# 324    False
# 325    False
# 326    False
# 327    False
# 328    False
# 329     True
# 330    False
# 331    False
# 332    False
# 333    False
# 334     True
# 335    False
# 336    False
# 337    False
# 338    False
# 339    False
# 340    False
# 341     True
# Name: Sex, Length: 342, dtype: bool

# %%
m = survived[survived.Sex == 'male'].Survived.count()
#print(m)
#print((survived.Sex == 'male').sum())

f = survived[survived.Sex == 'female'].Survived.count()

l = [m,f]
labels = 'Male','Female'
explode = (0.1,0.1)
plt.pie(l,labels=labels , autopct='%1.1f%%' , explode=explode , shadow = True)
plt.title("SURVIVED")
plt.show()
# Out:
# 109
# 109
